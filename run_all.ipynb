# %% [markdown]
# # Penney's Game
#
# The following three code blocks represent the three main functions used to interface with the code.
#
# `generate_data` creates the desired number of decks, and saves them to a `.npy` file in `data/`.
#
# `process_and_save_results` processes games using the specified deck data.
#
# `get_heatmaps` takes the results from `results/results.json` and creates visualizations.

# %%
import src.simulation as simulation
import importlib
importlib.reload(simulation)

#data is saved in data subfolder
#the first number in the name is n, the second is timestamp
simulation.generate_data(10000)
# Out:
# (100, 2)
# 100%|██████████| 100/100 [00:00<00:00, 38976.90it/s]
# 100 new decks saved to /home/carlo/Documents/GitHub/penney_final_revisions/data/deck_data_100_20241027_232548.npy

# %%
import src.processing as processing
importlib.reload(processing)

#select which data file to use
#save results in a results/temp folder
processing.process_and_save_results("data/deck_data.npy", "results/temp")
# Out:
# array(['0010100001110000110010011010101111001101110111001100',
#        '1101111010100111011000011001100010101000101000110011',
#        '0110111111010001110001000001101101100100010101001011', ...,
#        '1001110101111010111011010000001011100000010100011110',
#        '1110111001110000001001101101100111000110000010110011',
#        '0011111100001101101010011110000001001011010001001111'],
#       dtype=object)

# %%
import src.visualization as visualization
importlib.reload(visualization)

#use either "png" or "html"
#result is saved in figures folder
visualization.get_heatmaps("png")
