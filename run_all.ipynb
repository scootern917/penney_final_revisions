# %% [markdown]
# # Penney's Game
#
# The following three code blocks represent the three main functions used to interface with the code.
#
# `generate_data` creates the desired number of decks, and saves them to a `.npy` file in `data/`.
#
# `process_and_save_results` processes games using the specified deck data.
#
# `get_heatmaps` takes the results from `results/results.json` and creates visualizations.

# %%
import src.simulation as simulation
import importlib
importlib.reload(simulation)

#data is saved in data subfolder
#the first number in the name is n, the second is timestamp
simulation.generate_data(100000, verbose_name=True)
# Out:
# (100000, 2)
# 100%|██████████| 100000/100000 [00:01<00:00, 55513.97it/s]
# 100000 new decks saved to /home/carlo/Documents/GitHub/penney_final_revisions/data/deck_data_100000_20241028_123656.npy

# %%
import src.processing as processing
importlib.reload(processing)

#select which data file to use
#save results in a results/temp folder
processing.process_and_save_results("data/deck_data.npy", "results")
# Out:
# Loading decks...
# Processing games...
# Processing decks:   0%|          | 0/100000 [00:00<?, ?it/s]
# Processing decks: 100%|██████████| 100000/100000 [01:54<00:00, 870.46it/s]
# {'cards': [[0.0, 0.47146, 0.27852, 0.17867, 1e-05, 0.25404, 0.00937, 0.48664],
#   [0.50859, 0.0, 0.86262, 0.95541, 0.00199, 0.91649, 0.47652, 0.98833],
#   [0.70517, 0.12499, 0.0, 0.4852, 0.41967, 0.48818, 0.07003, 0.72578],
#   [0.80165, 0.03611, 0.48652, 0.0, 0.48554, 0.55998, 0.99746, 0.99997],
#   [0.99999, 0.99758, 0.5587, 0.48503, 0.0, 0.48561, 0.03773, 0.80485],
#   [0.7234, 0.06882, 0.48762, 0.41874, 0.48628, 0.0, 0.12443, 0.70536],
#   [0.9882, 0.47943, 0.91562, 0.00206, 0.95401, 0.86198, 0.0, 0.50857],
#   [0.48497, 0.00906, 0.25309, 3e-05, 0.1752, 0.27907, 0.47206, 0.0]],
#  'tricks': [[0.0,
#    0.40406,
#    0.21177,
#    0.11271,
#    0.00098,
#    0.16897,
#    0.00842,
#    0.32723],
#   [0.43992, 0.0, 0.79944, 0.88201, 0.02605, 0.79132, 0.40816, 0.96679],
#   [0.66389, 0.11837, 0.0, 0.43186, 0.42244, 0.4055, 0.11604, 0.6933],
#   [0.76887, 0.05298, 0.43294, 0.0, 0.43173, 0.44421, 0.93606, 0.99495],
#   [0.99515, 0.93586, 0.44157, 0.43264, 0.0, 0.4323, 0.0535, 0.76968],
#   [0.69211, 0.1142, 0.40717, 0.42124, 0.4322, 0.0, 0.11792, 0.66364],
#   [0.96627, 0.40996, 0.78858, 0.0261, 0.88037, 0.80104, 0.0, 0.4413],
#   [0.32442, 0.00812, 0.16878, 0.00107, 0.11297, 0.2134, 0.40326, 0.0]],
#  'cards_ties': [[0.0,
#    0.01995,
#    0.01631,
#    0.01968,
#    0.0,
#    0.02256,
#    0.00243,
#    0.02839],
#   [0.01995, 0.0, 0.01239, 0.00848, 0.00043, 0.01469, 0.04405, 0.00261],
#   [0.01631, 0.01239, 0.0, 0.02828, 0.02163, 0.0242, 0.01435, 0.02113],
#   [0.01968, 0.00848, 0.02828, 0.0, 0.02943, 0.02128, 0.00048, 0.0],
#   [0.0, 0.00043, 0.02163, 0.02943, 0.0, 0.02811, 0.00826, 0.01995],
#   [0.02256, 0.01469, 0.0242, 0.02128, 0.02811, 0.0, 0.01359, 0.01557],
#   [0.00243, 0.04405, 0.01435, 0.00048, 0.00826, 0.01359, 0.0, 0.01937],
#   [0.02839, 0.00261, 0.02113, 0.0, 0.01995, 0.01557, 0.01937, 0.0]],
#  'tricks_ties': [[0.0,
#    0.15602,
#    0.12434,
#    0.11842,
#    0.00387,
#    0.13892,
#    0.02531,
#    0.34835],
#   [0.15602, 0.0, 0.08219, 0.06501, 0.03809, 0.09448, 0.18188, 0.02509],
#   [0.12434, 0.08219, 0.0, 0.1352, 0.13599, 0.18733, 0.09538, 0.13792],
#   [0.11842, 0.06501, 0.1352, 0.0, 0.13563, 0.13455, 0.03784, 0.00398],
#   [0.00387, 0.03809, 0.13599, 0.13563, 0.0, 0.1355, 0.06613, 0.11735],
#   [0.13892, 0.09448, 0.18733, 0.13455, 0.1355, 0.0, 0.08104, 0.12296],
#   [0.02531, 0.18188, 0.09538, 0.03784, 0.06613, 0.08104, 0.0, 0.15544],
#   [0.34835, 0.02509, 0.13792, 0.00398, 0.11735, 0.12296, 0.15544, 0.0]],
#  'n': 100000}

# %%
import src.visualization as visualization
importlib.reload(visualization)

#use either "png" or "html"
#result is saved in figures folder
visualization.get_heatmaps("png")
